# %%
# 1) How-to-count-distance-to-the-previous-zero
#   For each value, 
#     count the difference back to the previous zero (or the start of the Series,whichever is closer)
#     create a new column 'Y'

#   Consider a DataFrame df where there is an integer column 'X'
#   import pandas as pd
#   df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})

import pandas as pd
import numpy as np
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2,5, 0, 3, 4]})
zeroIndices = df.index[df.X == 0]
Yvalues = []
j=len(zeroIndices)-1
for i in reversed(range(len(df.X))):
    if(i< zeroIndices[j]):
        Yvalues.append(i+1)
    elif (i==zeroIndices[j]):
        Yvalues.append(0)
        j-=1
    elif (i>zeroIndices[j]):
        Yvalues.append(i - zeroIndices[j])
        
Yvalues.reverse() 
df["Y"] = Yvalues
df
# Out:
#    X  Y
# 0  7  1
# 1  2  2
# 2  0  0
# 3  3  1
# 4  4  2
# 5  2  3
# 6  5  4
# 7  0  0
# 8  3  1
# 9  4  2

# %%
# 2) Create a DatetimeIndex that contains each business day of 2015 and use it to index a Series 's' of random numbers.

dateTimeIndex= pd.date_range(start="01/01/2015", end="31/12/2015", freq="B") # Creating a DateTime List for all business days
s = pd.Series(np.random.randint(0,10000,size=len(dateTimeIndex)), index=dateTimeIndex, name="RandNumbers")
print(s)
# Out:
# 2015-01-01    6063
# 2015-01-02    3173
# 2015-01-05    3313
# 2015-01-06    9663
# 2015-01-07    4753
# 2015-01-08    8602
# 2015-01-09    7310
# 2015-01-12     832
# 2015-01-13    3140
# 2015-01-14    8578
# 2015-01-15    7604
# 2015-01-16     736
# 2015-01-19    8431
# 2015-01-20     438
# 2015-01-21    5279
# 2015-01-22    5384
# 2015-01-23    7926
# 2015-01-26    4148
# 2015-01-27    9140
# 2015-01-28    2576
# 2015-01-29    2072
# 2015-01-30    1216
# 2015-02-02    1424
# 2015-02-03    6046
# 2015-02-04    9468
# 2015-02-05    2760
# 2015-02-06    2166
# 2015-02-09    1654
# 2015-02-10    4595
# 2015-02-11     477
#               ...
# 2015-11-20    1122
# 2015-11-23    5565
# 2015-11-24    2279
# 2015-11-25    3499
# 2015-11-26    6725
# 2015-11-27    6072
# 2015-11-30     380
# 2015-12-01     530
# 2015-12-02    5245
# 2015-12-03    3893
# 2015-12-04    7778
# 2015-12-07    5614
# 2015-12-08    9097
# 2015-12-09    6964
# 2015-12-10    4243
# 2015-12-11    6554
# 2015-12-14    8328
# 2015-12-15    2531
# 2015-12-16    1454
# 2015-12-17    7547
# 2015-12-18    4925
# 2015-12-21    6529
# 2015-12-22     802
# 2015-12-23    2587
# 2015-12-24    5534
# 2015-12-25    3162
# 2015-12-28    7164
# 2015-12-29    7216
# 2015-12-30    3817
# 2015-12-31    3285
# Freq: B, Name: RandNumbers, Length: 261, dtype: int32

# %%
# 3) Find the sum of the values in s for every Wednesday

allWednesdaySum = s[s.index.day ==2].sum() #Adding all the random numbers associated with every wednesday of the year
print("Sum of all random numbers on wednesday in 2015: ", allWednesdaySum)
print()

# 4) Average For each calendar month

monthlyAverage = [s[s.index.month == i].mean() for i in range(1,13)] #Calculating the average for every month
print("Average of every Calender Month: ", np.around(monthlyAverage, 2)) # Formatting the averages in list to show precision of 2 decimal points
print()

# 5) For each group of four consecutive calendar months in s, find the date on which the highest value occurred.

fourMonthHighestDates = s.index[s.isin(s.groupby([((s.index.month -1)/4).astype("int64", copy=True)] ).max())]
print("Dates for which the highest value occured in every 4 months in 2015  along with the values: ")
fourMonthHighestDates
# Out:
# Sum of all random numbers on wednesday in 2015:  40177
#
# Average of every Calender Month:  [5017.14 4499.15 4441.77 4769.5  4899.57 6025.18 3946.96 4394.67 3966.5
#  4416.14 5611.14 4991.26]
#
# Dates for which the highest value occured in every 4 months in 2015  along with the values:
# DatetimeIndex(['2015-04-24', '2015-06-17', '2015-09-21'], dtype='datetime64[ns]', freq=None)
